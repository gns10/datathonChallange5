# %%
import joblib

# Exemplo de leitura de um arquivo .pkl
dados = joblib.load(
    r'C:\Users\gusta\Desktop\datathon\datathonChallange5\stDatathon\modelo_risco_defasagem.pkl'
)

print(dados)
# Out:
# {'model': LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42), 'scaler': StandardScaler(), 'imputer': SimpleImputer(strategy='median'), 'features': ['IDA', 'IEG', 'IPS', 'IPP', 'IAN', 'IDADE', 'GENERO', 'TEMPO_ASSOCIACAO', 'ENSINO_GRUPO_Privada', 'ENSINO_GRUPO_Pública'], 'threshold': 0.5}
